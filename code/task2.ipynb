# %% [markdown]
# # Predict the topics of each story

# %% [markdown]
# ______________________________________________________________________

# %% [markdown]
# ##  1- Import libraries

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
import re
import os
from task1 import add_columns

# %% [markdown]
# ##  2- Load the datas

# %%
df_train=pd.read_csv('../data/stories.csv')
df_test=pd.read_csv('../data/to_fill.csv')

# %% [markdown]
# ## 3- Preprocessing data
# - Dealing with missing data
# - Removing Stop words
# - Lower casing
# - Tokenization
# - Stemming
# - Lemmatization

# %% [markdown]
#     -Dealing with missing data

# %%
np.shape(df_train) 
# output:
    # (5181, 2)
    
df_train.isna().sum()
# output:
    # body     0
    # topic    0
    # dtype: int64

df_train = df_train.replace(' ', np.nan)
df_train.isna().sum()
# output:
    # body     29
    # topic     0
    # dtype: int64

# The number of missing data is less than 10% of the total data, so deleting them is the best way.
df_train = df_train.dropna()
np.shape(df_train) 
# output:
    # (5152, 2)

df_train.head()
# Out:
#                                                  body
# 4   hello and welcome to BBC News a woman who gave...  \
# 8   news now out of North Hollywood. A 14 yearold ...
# 11  homelessness his city's greatest failure. That...
# 12  Minneapolis police officer Kim Potter guilty o...
# 15  Judy an update now to the wildfires that wiped...
#
#                                                 topic
# 4   ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
# 8            ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 11  ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '74e2...
# 12  ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
# 15  ['9ff54ded-904b-4e0c-85ce-a3617f5cb913', '9a06...

# %% [markdown]
#     -Preprocessing text

# %%
stemmer = PorterStemmer()
def process_text(text):
    # Make all the strings lowercase and remove non alphabetic characters
    text = re.sub('[^A-Za-z]', ' ', text.lower())

    # Tokenize the text
    tokenized_text = word_tokenize(text)

    # Remove the stopwords and stem each word to its root
    clean_text = [
        stemmer.stem(word) for word in tokenized_text
        if word not in stopwords.words('english')
    ]
    
    return clean_text

# %% [markdown]
# ## 4- Prepare training data ,  test data and validation data

# %%
bodies_train=np.array(df_train['body'])
topics_train=np.array(df_train['topic'])
bodies_test=np.array(df_test['body'])

# %%
# Process the texts 
# transform the list of words back to string format to feed it to sklearn
bodies_train = [" ".join(process_text(body)) for body in bodies_train]
bodies_test = [" ".join(process_text(body)) for body in bodies_test if body!='Not found']

# %%
X_train, X_val, y_train, y_val = train_test_split(bodies_train,
                                                  topics_train,
                                                  test_size=0.2,
                                                  shuffle=True)

# %% [markdown]
# ## 5- Convert text to vector

# %%
matrix = CountVectorizer()
ve_X_train=matrix.fit_transform(X_train).toarray()
ve_X_val=matrix.transform(X_val).toarray()
ve_X_test=matrix.transform(bodies_test).toarray()

# %% [markdown]
# ## 6- Training a Naive Bayes classifier

# %%
classifier = GaussianNB()
# ['ca197b81-ca86-4792-8c25-2ba7cd4195b5', '9ff54ded-904b-4e0c-85ce-a3617f5cb913', '96326734-fd82-4350-b45c-513e7eb9147c']       0.00      0.00      0.00         1
#                                         ['ca197b81-ca86-4792-8c25-2ba7cd4195b5', '9ff54ded-904b-4e0c-85ce-a3617f5cb913']       0.00      0.00      0.00         4
#                                         ['ca197b81-ca86-4792-8c25-2ba7cd4195b5', 'a58b4b70-1b59-4240-917d-a2165a0ce2f0']       0.00      0.00      0.00         1
#                                         ['ca197b81-ca86-4792-8c25-2ba7cd4195b5', 'b49207eb-96eb-4b73-b534-adc0ef85022a']       0.00      0.00      0.00         2
#                                         ['ca197b81-ca86-4792-8c25-2ba7cd4195b5', 'ebf2991e-4b7d-44c6-927b-a261a7b21d2c']       1.00      0.20      0.33         5
#                                                                                 ['ca197b81-ca86-4792-8c25-2ba7cd4195b5']       0.57      0.21      0.31        19
#                                                                                 ['e7cbe38d-c987-4113-aa94-fd77eda451d5']       0.00      0.00      0.00         1
#                                         ['ebf2991e-4b7d-44c6-927b-a261a7b21d2c', 'b49207eb-96eb-4b73-b534-adc0ef85022a']       0.00      0.00      0.00         0
#                                                                                 ['ebf2991e-4b7d-44c6-927b-a261a7b21d2c']       0.40      0.14      0.21        14
#                                         ['f5cdd7f2-9d4d-4ba5-9925-00c1701e30fa', '9a06646a-e1df-4fca-888e-69658420556b']       0.00      0.00      0.00         2
#                                                                                 ['f5cdd7f2-9d4d-4ba5-9925-00c1701e30fa']       0.00      0.00      0.00         3
#
#                                                                                                                 accuracy                           0.40      1031
#                                                                                                                macro avg       0.17      0.10      0.11      1031
#                                                                                                             weighted avg       0.36      0.40      0.35      1031
# c:\users\fsg\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\fsg\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\fsg\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\fsg\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\fsg\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\fsg\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## 7- Testing the model on unlabelled dataset

# %%
topics_pred = classifier.predict(ve_X_test)

# %% [markdown]
# ## 8-Add topic column to dataframe

# %%
topic=[]
j=0
for body in df_test['body']:
    if body!='Not found':
        topic.append(topics_pred[j])
        j+=1
    else:
        topic.append('Not found')

# %%
add_columns(df_test,['topic'],[topic])
# Out:
#                                           first_words
# 0       Well knew. This morning police need your help  \
# 1    a call. San Francisco firefighters rescued a man
# 2          Paul. Meanwhile, the state set a record in
# 3   Emergency crews in Florida continue to search for
# 4     But even though the state never ordered rolling
# 5       aid. And today, president Joe Biden and first
# 6         In the last month, there have been numerous
# 7     and the warriors are playing the Boston Celtics
# 8     And San Leandro police searching for the person
# 9   The updated Bivalent Coronavirus booster shot ...
# 10  temperatures tonight, only back down to the un...
# 11           And National Guard teams are also on the
# 12         A man died after falling from an escalator
# 13  All right. Well happening today. Friends and f...
# 14   detectives are searching for six people they say
# 15        San Jose police say a security guard trying
# 16    San Jose police just announcing today an arrest
# 17  shooting. Surveillance video shows how a car t...
#
#                                            last_words  source_video_id
# 0   gunpoint, beating him and stealing his cell ph...            18246  \
# 1               all the way down to the ocean. ocean.            12387
# 2   night through conservation, some 4000 conserva...            16859
# 3             in Florida to more than 850,000 homes.             18246
# 4      feel since their power got cut out needlessly.            16859
# 5    to view the destruction caused by Hurricane Ian.            18246
# 6       are necessary to crack down on those hackers.            18246
# 7             that. We'll see if they get it tonight.            12387
# 8   footage to try to piece together more informat...            16859
# 9   on their vaccinations getting severe illness f...            16859
# 10  stuff. Stay hydrated, take breaks. Don't overd...            16859
# 11  north and South Carolina. Fasttracking federal...            18246
# 12               name or what led to that fall. fall.            18246
# 13  Meanwhile, the suspected killer remains in the...            18246
# 14      with any information is asked to call police.            18246
# 15         not released yet by the Santa Clara County            12387
# 16       not reveal a motive for the deadly shooting.            12387
# 17               this case, please give them a call.             12387
#
#                                                  body      start        end
# 0   Well knew. This morning police need your help ...     464928     504300  \
# 1                                           Not found  Not found  Not found
# 2   Paul. Meanwhile, the state set a record in ene...      60704     100410
# 3   Emergency crews in Florida continue to search ...     505290     534958
# 4   But even though the state never ordered rollin...     100910     283306
# 5   aid. And today, president Joe Biden and first ...     546494     592450
# 6   In the last month, there have been numerous da...     614910     699230
# 7   and the warriors are playing the Boston Celtic...     419994     649122
# 8   And San Leandro police searching for the perso...     578612     618980
# 9   The updated Bivalent Coronavirus booster shot ...     619310     659730
# 10  temperatures tonight, only back down to the un...    1127008    1207970
# 11  And National Guard teams are also on the groun...     534674     547150
# 12                                          Not found  Not found  Not found
# 13  All right. Well happening today. Friends and f...     218170     345318
# 14  detectives are searching for six people they s...     350830     459134
# 15  San Jose police say a security guard trying to...      98130     275802
# 16  San Jose police just announcing today an arres...     283804     330330
# 17  shooting. Surveillance video shows how a car t...     329682     360102
#
#                                                 topic
# 0            ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 1                                           Not found
# 2            ['83a09c6b-5f2f-421f-ae50-b38acca7e008']
# 3            ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 4            ['83a09c6b-5f2f-421f-ae50-b38acca7e008']
# 5            ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 6            ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 7            ['b49207eb-96eb-4b73-b534-adc0ef85022a']
# 8   ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
# 9            ['96326734-fd82-4350-b45c-513e7eb9147c']
# 10           ['0d817400-3f5d-41e0-929c-c31fdbe75d31']
# 11           ['83a09c6b-5f2f-421f-ae50-b38acca7e008']
# 12                                          Not found
# 13  ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
# 14           ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 15           ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 16  ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
# 17           ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']

# %% [markdown]
# ## 9- Convert dataframe to csv and rename file

# %%
df_test.to_csv('../data/to_fill.csv',index=False)
os.rename('../data/to_fill.csv','../data/filled.csv')
